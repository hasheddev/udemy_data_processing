# %%
import pandas as pd
netflix = pd.read_csv('../data/netflix_titles.csv', sep='|')

# %%
netflix.set_index('show_id', inplace=True)

# %%
netflix.loc['s2202', ['director']] = 'Greg Whitely'
netflix.loc['s2202', ['director']]
# Out:
# director    Greg Whitely
# Name: s2202, dtype: object

# %%
netflix.loc[['s2881', 's3601'], ['duration']] = 'Gone Too Soon'

# %%
netflix.loc[['s2881', 's3601']]
# Out:
#          Unnamed: 0     type                    title director  \
# show_id
# s2881          2880  TV Show  I Am Not Okay With This      NaN
# s3601          3600  TV Show                     GLOW      NaN
#
#                                                       cast        country  \
# show_id
# s2881    Sophia Lillis, Wyatt Oleff, Kathleen Rose Perk...  United States
# s3601    Alison Brie, Betty Gilpin, Marc Maron, Britney...  United States
#
#                 date_added  release_yr rating       duration  \
# show_id
# s2881    February 26, 2020        2020  TV-MA  Gone Too Soon
# s3601       August 9, 2019        2019  TV-MA  Gone Too Soon
#
#                                            listed_in  \
# show_id
# s2881    TV Comedies, TV Dramas, TV Sci-Fi & Fantasy
# s3601                         TV Comedies, TV Dramas
#
#                                                description  is_false  is_fav
# show_id
# ...

# %%
netflix.rename(columns={'release_year': 'release_yr'}, inplace=True)
#netflix.rename({'release_year': 'release_yr'}, axis=1, inplace=True)
#netflix.rename({'release_year': 'release_yr'}, inplace=True) updates label/index

# %%
netflix[netflix.title == 'Evil']
netflix.rename(index={'s1907': 's6666'}, inplace=True)

# %%
netflix.rating.replace(['NR', 'UR'], 'No Rating').value_counts()
#netflix.rating = netflix.rating.replace('NR', 'No Rating')
# Out:
# rating
# TV-MA        3207
# TV-14        2160
# TV-PG         863
# R             799
# PG-13         490
# TV-Y7         334
# TV-Y          307
# PG            287
# TV-G          220
# No Rating      83
# G              41
# TV-Y7-FV        6
# NC-17           3
# 74 min          1
# 84 min          1
# 66 min          1
# Name: count, dtype: int64

# %%
netflix.rating.value_counts()
# Out:
# rating
# TV-MA        3207
# TV-14        2160
# TV-PG         863
# R             799
# PG-13         490
# TV-Y7         334
# TV-Y          307
# PG            287
# TV-G          220
# No Rating      83
# G              41
# TV-Y7-FV        6
# NC-17           3
# 74 min          1
# 84 min          1
# 66 min          1
# Name: count, dtype: int64

# %%
netflix['is_fav'] = False

# %%
names = ['Young Royals', 'Dark', 'Big Mouth', 'BoJack Horseman', 'Godless', 'Russian Doll', 'American Vandal', "The Queen's Gambit"]
netflix.loc[netflix.title.isin(names), 'is_fav'] = True
