# %% [markdown]
# A Pandas DataFrame is a two-dimensional, size-mutable, and tabular data structure with labeled axes (rows and columns)
# A Pandas Series is a one-dimensional labeled array capable of holding data of any type, such as integers, floats, strings, and Python objects. It can be for a column or for multiple aggregates like sum and labe can be numeric/string

# %%
import pandas as pd
#df.column or df['column'] (safer)
houses = pd.read_csv('../data/kc_house_data.csv')
titanic = pd.read_csv('../data/titanic.csv')
netflix = pd.read_csv('../data/netflix_titles.csv', sep='|', index_col=0)

# %%
type(titanic.name) #hoes not work with special characters like space, dot etc
# Out:
# pandas.core.series.Series

# %%
type(titanic['name'])
# Out:
# pandas.core.series.Series

# %%
property = 'price'
houses[property]
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
houses.sum()
# Out:
# id                                                  98994056770455
# date             20141013T00000020141209T00000020150225T0000002...
# price                                                11672925008.0
# bedrooms                                                     72854
# bathrooms                                                 45706.25
# sqft_living                                               44952873
# sqft_lot                                                 326506890
# floors                                                     32296.5
# waterfront                                                     163
# view                                                          5064
# condition                                                    73688
# grade                                                       165488
# sqft_above                                                38652488
# sqft_basement                                              6300385
# ...

# %%
houses.price.sum()
# Out:
# np.float64(11672925008.0)

# %%
houses.price.shape
# Out:
# (21613,)

# %%
houses.price.values
# Out:
# array([221900., 538000., 180000., ..., 402101., 400000., 325000.],
#       shape=(21613,))

# %%
houses.price.index    #label can be nummeric or an array os strings
# Out:
# RangeIndex(start=0, stop=21613, step=1)

# %%
houses.price.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 21613 entries, 0 to 21612
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 21613 non-null  float64
# dtypes: float64(1)
# memory usage: 169.0 KB

# %% [markdown]
# - head()
# - tail()
# - describe()
# - unique()
# - nunique()
# - nlargest()
# - nsmallest()
# - value_counts()
# - plot()

# %%
netflix.title.head()
# Out:
# 0     Dick Johnson Is Dead
# 1            Blood & Water
# 2                Ganglands
# 3    Jailbirds New Orleans
# 4             Kota Factory
# Name: title, dtype: object

# %%
netflix.title.tail(30)
# Out:
# 8777                        Yes or No
# 8778                      Yes or No 2
# 8779                    Yes or No 2.5
# 8780                     Yo-Kai Watch
# 8781          Yo-Kai Watch: The Movie
# 8782                      Yoga Hosers
# 8783                             Yoko
# 8784             Yoko and His Friends
# 8785                              YOM
# 8786                     You Can Tutu
# 8787        You Can’t Fight Christmas
# 8788                     You Carry Me
# 8789              You Changed My Life
# 8790    You Don't Mess with the Zohan
# 8791                      Young Adult
# 8792                      Young Tiger
# 8793             Yours, Mine and Ours
# 8794                           اشتباك
# 8795                  Yu-Gi-Oh! Arc-V
# 8796                       Yunus Emre
# 8797                        Zak Storm
# 8798                         Zed Plus
# 8799                            Zenda
# 8800               Zindagi Gulzar Hai
# 8801                          Zinzana
# ...

# %%
netflix.title.describe()
# Out:
# count                     8807
# unique                    8807
# top       Dick Johnson Is Dead
# freq                         1
# Name: title, dtype: object

# %%
netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
netflix.rating.dtypes
# Out:
# dtype('O')

# %%
#unique works only on Series and not dataframe
houses.bedrooms.unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33])

# %%
houses.bedrooms.nunique() #unique ignores n/a|missing values
# Out:
# 13

# %%
netflix.head() #nan is missing values and unique dos not include it
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix.rating.nunique()
# Out:
# 17

# %%
netflix.rating.nunique(dropna=False) #default is true
# Out:
# 18

# %%
netflix.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
#nlarges and nsmallest are both series and dataframe methods

# %%
houses.price.nlargest() #houses.price.nlargest(9)
# Out:
# 7252    7700000.0
# 3914    7062500.0
# 9254    6885000.0
# 4411    5570000.0
# 1448    5350000.0
# Name: price, dtype: float64

# %%
houses.price.nsmallest(9)
# Out:
# 1149     75000.0
# 15293    78000.0
# 465      80000.0
# 16198    81000.0
# 8274     82000.0
# 2141     82500.0
# 18468    83000.0
# 3767     84000.0
# 10253    85000.0
# Name: price, dtype: float64

# %%
titanic.pclass.nlargest(5, keep='all') #keep duplicates
# Out:
# 600     3
# 601     3
# 602     3
# 603     3
# 604     3
#        ..
# 1304    3
# 1305    3
# 1306    3
# 1307    3
# 1308    3
# Name: pclass, Length: 709, dtype: int64

# %%
#houses.nlargest() #error
houses.nlargest(10, ['price']) #10 largest rows based on price
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 8092  1924059029  20140617T000000  4668000.0         5       6.75
# 2626  7738500731  20140815T000000  4500000.0         5       5.50
# 8638  3835500195  20140618T000000  4489000.0         4       3.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# ...

# %%
houses.nlargest(10, ['bedrooms', 'bathrooms'])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 16844  8823900290  20150317T000000  1400000.0         9       4.00
# 4235   2902200015  20150106T000000   700000.0         9       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# 8757          3000      4960     2.0           0     0  ...      7
# ...

# %%
#multiple column selection  returns a data frame
netflix[['title', 'rating']]
# Out:
#                       title rating
# 0      Dick Johnson Is Dead  PG-13
# 1             Blood & Water  TV-MA
# 2                 Ganglands  TV-MA
# 3     Jailbirds New Orleans  TV-MA
# 4              Kota Factory  TV-MA
# ...                     ...    ...
# 8802                 Zodiac      R
# 8803            Zombie Dumb  TV-Y7
# 8804             Zombieland      R
# 8805                   Zoom     PG
# 8806                 Zubaan  TV-14
#
# [8807 rows x 2 columns]

# %%
#value_count  returns a series containing counts of unique values in descending order
houses['bedrooms'].value_counts()
# Out:
# bedrooms
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: count, dtype: int64

# %%
type(houses['bedrooms'].value_counts())
# Out:
# pandas.core.series.Series

# %%
titanic.sex.value_counts() #acesnding=False by default
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
houses.floors.value_counts()
# Out:
# floors
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: count, dtype: int64

# %%
houses[['bedrooms', 'bathrooms']]
# Out:
#        bedrooms  bathrooms
# 0             3       1.00
# 1             3       2.25
# 2             2       1.00
# 3             4       3.00
# 4             3       2.00
# ...         ...        ...
# 21608         3       2.50
# 21609         4       2.50
# 21610         2       0.75
# 21611         3       2.50
# 21612         2       0.75
#
# [21613 rows x 2 columns]

# %%
houses[['bedrooms', 'bathrooms']].value_counts()
#returns a series showing the unique combinations of 'bedrooms' and 'bathrooms' along with how many times each combination appears in your dataset
#the label is a combination of bedrooms bathrooms
# Out:
# bedrooms  bathrooms
# 4         2.50         2502
# 3         2.50         2357
#           1.75         1870
#           1.00         1780
# 2         1.00         1558
#                        ...
# 7         1.00            1
#           3.25            1
#           5.50            1
#           5.75            1
# 33        1.75            1
# Name: count, Length: 144, dtype: int64

# %%
houses.bedrooms.plot() #line plot is the defaul plotting values against a label
# Out:
# <Axes: >

# %%
houses.bedrooms.value_counts().plot()
# Out:
# <Axes: xlabel='bedrooms'>

# %%
houses.bedrooms.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='bedrooms'>

# %%
houses.bedrooms.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
titanic.survived.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
houses.plot()  #plot every single column
# Out:
# <Axes: >

# %%
houses[['bathrooms', 'bedrooms']].plot()
# Out:
# <Axes: >

# %%
df = houses[['bathrooms', 'bedrooms']]
df.plot(x='bathrooms', y='bedrooms', kind='scatter')
# Out:
# <Axes: xlabel='bathrooms', ylabel='bedrooms'>

# %%
netflix.rating.value_counts().head(15).plot(kind='bar')
# Out:
# <Axes: xlabel='rating'>
