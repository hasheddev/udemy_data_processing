# %%
import pandas as pd

pd.to_datetime('2019-12-31')
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
pd.to_datetime('2019/12/31')
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
pd.to_datetime('December 31st 2019')
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
pd.to_datetime('December 31st 2019 4:50am')

# %%
pd.to_datetime('3:55:45 Apr. 2nd 90') # can take a lis retut of dates to convert returning a date index
# Out:
# Timestamp('1990-04-02 03:55:45')

# %%
pd.to_datetime('10/11/12', dayfirst=True)
# Out:
# Timestamp('2012-11-10 00:00:00')

# %%
pd.to_datetime('10/11/12', yearfirst=True)
# Out:
# Timestamp('2010-11-12 00:00:00')

# %%
pd.to_datetime('10/11/12', format='%y/%m/%d')
# Out:
# Timestamp('2010-11-12 00:00:00')

# %%
meetings = ['Dec 11 2019 Meeting', 'Nov 6 2020 Meeting']
pd.to_datetime(meetings, format="%b %d %Y Meeting")
# Out:
# DatetimeIndex(['2019-12-11', '2020-11-06'], dtype='datetime64[ns]', freq=None)

# %%
ufos = pd.read_csv('../data/nuforc_reports.csv')

# %%
ufos['date'] = pd.to_datetime(ufos.date_time)

# %%
ufos = pd.read_csv('../data/nuforc_reports.csv', parse_dates=['date_time'])

# %%
#accessing date time
ufos.date_time.dt.year.value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='date_time'>

# %%
ufos.date_time.dt.month.value_counts().sort_index()
# Out:
# date_time
# 1.0      5979
# 2.0      4559
# 3.0      5494
# 4.0      5817
# 5.0      6063
# 6.0      8357
# 7.0     10682
# 8.0      8997
# 9.0      8498
# 10.0     8371
# 11.0     7596
# 12.0     6525
# Name: count, dtype: int64

# %%
ufos.date_time.dt.day.value_counts()
# Out:
# date_time
# 1.0     4852
# 15.0    4403
# 4.0     3864
# 20.0    3016
# 12.0    2945
# 10.0    2923
# 24.0    2831
# 25.0    2805
# 30.0    2793
# 7.0     2776
# 5.0     2755
# 14.0    2739
# 22.0    2723
# 3.0     2708
# 19.0    2681
# 18.0    2678
# 11.0    2639
# 8.0     2635
# 23.0    2634
# 13.0    2634
# 17.0    2607
# 21.0    2602
# 16.0    2598
# 6.0     2578
# 28.0    2555
# 27.0    2531
# 9.0     2443
# 26.0    2430
# 2.0     2425
# 29.0    2364
# 31.0    1771
# Name: count, dtype: int64

# %%
ufos.date_time.dt.hour.value_counts()
# Out:
# date_time
# 21.0    12851
# 22.0    11660
# 20.0     9565
# 23.0     8194
# 19.0     6460
# 0.0      5577
# 18.0     4462
# 1.0      3285
# 17.0     2660
# 2.0      2216
# 3.0      2088
# 5.0      1874
# 4.0      1641
# 16.0     1612
# 6.0      1588
# 12.0     1408
# 15.0     1380
# 10.0     1334
# 13.0     1308
# 11.0     1301
# 14.0     1280
# 9.0      1126
# 7.0      1067
# 8.0      1001
# Name: count, dtype: int64

# %%
ufos.date_time.dt.day_of_week.value_counts()
# Out:
# date_time
# 5.0    16305
# 4.0    12864
# 6.0    12652
# 3.0    11729
# 2.0    11646
# 1.0    10987
# 0.0    10755
# Name: count, dtype: int64

# %%
#comparing dates
ufos[ufos.date_time < '1980'] #month / day does not work
# Out:
#                                                  summary  \
# 8      Ufos report in Irving Texas at 2200 hrs. On or...
# 15        Strange bright light hovered over mobile home.
# 31     Bright green round object quickly travelling e...
# 54     It was a full moon when my brother and I obser...
# 55              UFO over Orangevale, CA in May/June 1969
# ...                                                  ...
# 87166  VERY LARGE OBJECT- WHITE LIGHT ILLUMINATING MY...
# 87167  7 "PEARLESCENT" HIGH ALTITUDE CRAFT IN V FORMA...
# 87168  The even occurred North of Mt Calvary Rd on Ol...
# 87169  Triangle ship passed over silent with 7 green ...
# 87170  While trick or treating with Mom, my Grandma p...
#
#                         city state           date_time     shape  \
# 8                     Dallas    TX 1973-07-14 22:00:00      oval
# 15                Gray Court    SC 1975-07-17 00:00:00     light
# 31     N. Cascades Nat. Park    WA 1979-07-15 23:00:00     light
# ...

# %%
ufos[ufos.date_time > '2019-12-23'] #equality makes it harder
# Out:
#                                                  summary        city state  \
# 85714  7-8 elongated objects flying in straight line ...  Wilmington    NC
#
#                 date_time  shape    duration  \
# 85714 2019-12-29 20:40:00  cigar  10 seconds
#
#                                                    stats  \
# 85714  Occurred : 11/29/2019 20:40  (Entered as : 12/...
#
#                                              report_link  \
# 85714  http://www.nuforc.org/webreports/151/S151158.html
#
#                                                     text               posted  \
# 85714  7-8 elongated objects flying in straight line ...  2019-12-01T00:00:00
#
#        city_latitude  city_longitude
# 85714      34.238375      -77.878468

# %%
ufos[ufos.date_time.dt.hour == 2.0].head()
# Out:
#                                                summary         city state  \
# 3    I was driving towards the intersection of fall...       Ottawa    ON
# 14   Bright Circle of Light followed me from Oskalo...  Centerville    IA
# 148                              Strange Vibrations...    Indianola    IA
# 153  red ball ufo following small plane in tracy, c...        Tracy    CA
# 181  Silver disk flies through sky making zigzaggin...    Beaverton    OR
#
#               date_time     shape     duration  \
# 3   2019-04-17 02:00:00  teardrop   10 seconds
# 14  1999-08-15 02:30:00    circle       1 hour
# 148 1992-04-30 02:00:00   unknown    5 Minutes
# 153 1993-06-15 02:00:00     light    3 minutes
# 181 2015-04-16 02:30:00      disk  5-8 minutes
#
#                                                  stats  \
# 3    Occurred : 4/17/2019 02:00  (Entered as : 04-1...
# 14   Occurred : 8/15/1999 02:30  (Entered as : 08/1...
# 148  Occurred : 4/30/1992 02:00  (Entered as : 04/3...
# ...

# %%
ufos[ufos.date_time.between('1988', '1989')]
# Out:
#                                                  summary  \
# 128    Triangle craft with one large softwhite light ...
# 129    -Working the night shift,and always watching t...
# 130    one shining spiral  moves fast from southwest ...
# 134    Charbonneau Park, Rosemere, PQ. Diamond shaped...
# 750    what are those two 5-6 ft spheres floating on ...
# ...                                                  ...
# 81661  4 days of missing time while working in a remo...
# 82524  Very bright light moving from South to North, ...
# 82652  Beam of light with no sound; no indication of ...
# 84662  I was called to the back porch by my grandmoth...
# 87173  hovering saucer with colored lights flew and s...
#
#                           city state           date_time     shape  \
# 128                   Powhatan    VA 1988-03-08 05:20:00  triangle
# 129                     Woburn    MA 1988-06-20 01:00:00     light
# 130    Suzhou, Jiangsu (China)   NaN 1988-08-10 15:00:00    circle
# ...

# %%
ufos['date_time'].dt.date.value_counts()
# Out:
# date_time
# 2015-11-07    290
# 2014-07-04    270
# 2010-07-04    210
# 2012-07-04    200
# 2013-07-04    185
#              ...
# 1980-09-12      1
# 1988-06-13      1
# 1981-07-29      1
# 2004-07-04      1
# 2003-09-07      1
# Name: count, Length: 8351, dtype: int64

# %%
recent_seen = ufos[ufos['date_time'].dt.year >= 2018]
recent_seen.date_time.dt.date.value_counts()
# Out:
# date_time
# 2019-11-11    77
# 2019-05-25    69
# 2019-05-26    67
# 2019-05-24    60
# 2019-07-04    57
#               ..
# 2019-12-29     1
# 2018-02-08     1
# 2019-05-09     1
# 2018-02-04     1
# 2018-02-07     1
# Name: count, Length: 719, dtype: int64

# %%
ufos.posted = pd.to_datetime(ufos.posted)

# %%
ufos['time_before_report'] = ufos.posted - ufos.date_time

# %%
longest = ufos.sort_values('time_before_report', ascending=False).head(10)

# %%
longest['time_before_report'].dt.days /365
# Out:
# 86762    50.583562
# 87145    50.282192
# 721      50.175342
# 1576     50.101370
# 1580     49.972603
# 84984    49.586301
# 83965    49.213699
# 722      49.180822
# 723      49.052055
# 1301     48.967123
# Name: time_before_report, dtype: float64

# %%
billboards = pd.read_csv('../data/billboard_charts.csv', parse_dates=['date'])

# %%
billboards.artist.value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='artist'>

# %%
top = billboards['rank'] == 1
billboards[top]['artist'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='artist'>

# %%
billboards[top]['song'].value_counts()
# Out:
# song
# Old Town Road                               19
# Despacito                                   16
# One Sweet Day                               16
# Rockstar                                    15
# I'll Make Love To You                       14
#                                             ..
# Then Came You                                1
# You Haven't Done Nothin                      1
# You Ain't Seen Nothing Yet/Free Wheelin'     1
# Whatever Gets You Thru The Night             1
# I'll Take You There                          1
# Name: count, Length: 1104, dtype: int64

# %%
old_town_road = billboards[billboards["song"] == 'Old Town Road'].set_index('date')

# %%
p = old_town_road['rank'].plot().invert_yaxis()
