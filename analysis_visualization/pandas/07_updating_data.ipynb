# %%
import pandas as pd
houses = pd.read_csv('../data/kc_house_data.csv')
titanic = pd.read_csv('../data/titanic.csv')
netflix = pd.read_csv('../data/netflix_titles.csv', sep='|', index_col=0)
btc = pd.read_csv('../data/coin_Bitcoin.csv')
countries = pd.read_csv('../data/world-happiness-report-2021.csv', index_col=0)

# %%
titanic['sex'].replace(['female', 'male'], ['F', 'M']) #Series.replace
# Out:
# 0       F
# 1       M
# 2       F
# 3       M
# 4       F
#        ..
# 1304    F
# 1305    F
# 1306    M
# 1307    M
# 1308    M
# Name: sex, Length: 1309, dtype: object

# %%
titanic['sex'].replace('?', 'idk')  #titanic['sex'].replace('?', None)  does not work as expected use list
#titanic['sex'].replace(['?'], [None], inplace=True)no longer works  #value counts does not include none but using dropna=False gets them
titanic['age'] = titanic['age'].replace(['?'], [None]) #titanic.replace({'age': {'?': None}}, inplace=True

# %%
titanic.head(50)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
countries.loc[['Denmark'], ['Ladder score']]
# Out:
#               Ladder score
# Country name
# Denmark               7.62

# %%
countries.loc[['Denmark', 'Norway', 'Sweden'], ['Regional indicator']] = 'Scandinavia'

# %%
countries.loc[['Denmark', 'Norway', 'Sweden'], ['Regional indicator']]
# Out:
#              Regional indicator
# Country name
# Denmark             Scandinavia
# Norway              Scandinavia
# Sweden              Scandinavia

# %%
countries.loc[['Denmark', 'Norway', 'Sweden', 'Iceland'], ['Regional indicator']]
#countries.loc['Finland'] = 'LOL' sets all columns to LOL, countries.loc['Finland', ['col1', 'col2']] = 'value' sets given columns to value
#houses[['bedrooms', 'bathrooms']]
# Out:
#              Regional indicator
# Country name
# Denmark             Scandinavia
# Norway              Scandinavia
# Sweden              Scandinavia
# Iceland          Western Europe

# %%
countries.loc[['Denmark', 'Norway', 'Sweden', 'Iceland'], ['Regional indicator', 'is_cold']] = ['Nordic', 'yes'] #all other rows have Nan for newly added column
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark                   Nordic         7.620
# Switzerland       Western Europe         7.571
# Iceland                   Nordic         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
#Boolean masks in updates
many_rooms = houses['bedrooms'] >= 10
#houses.loc[many_rooms, ['bedrooms']] = 'too many!'  cast data beforeassignment
# Convert the whole column to string type first
#houses['bedrooms'] = houses['bedrooms'].astype(str)

# Now you can safely insert string values
#houses.loc[many_rooms, 'bedrooms'] = 'too many!'

# %%
houses['luxury_level'] = "normal"
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 0             1180      5650     1.0           0     0  ...        1180
# ...

# %%
great_views = houses['view'] == 4
high_quality = houses['grade'] > 12
houses.loc[great_views & high_quality, ['luxury_level']] = 'ultra'

# %%
houses.luxury_level.value_counts()
# Out:
# luxury_level
# normal    21610
# ultra         3
# Name: count, dtype: int64
